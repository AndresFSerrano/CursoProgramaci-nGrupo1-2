# %%
pensum=[{'0123':{'nombre':'intro a la ing','creditos':2},'4567':{'nombre':'inglés','creditos':1}},{},{}]

semestre='1'
codigo='0123'
materia='lectoescritura'
creditos=3


if (semestre=='1'):
    semestre1=pensum[0]
    if len(semestre1)==0:
        print('El semestre no tiene materias')
    else:
        codigos1=[]
        for i in semestre1.keys():
            codigos1.append(i)
        if codigo in codigos1:
           pensum[0][codigo]['nombre']=materia
           pensum[0][codigo]['créditos']=creditos
           print('Modificada con éxito')
        else:
           print('La materia no existe')
    
elif (semestre=='2'):
    semestre2=pensum[1]
    if len(semestre2)==0:
        print('El semestre no tiene materias')
    else:
        codigos2=[]
        for i in semestre2.keys():
            codigos2.append(i)
        if codigo in codigos2:
           pensum[0][codigo]['nombre']=materia
           pensum[0][codigo]['créditos']=creditos
           print('Modificada con éxito')
        else:
           print('La materia no existe')
elif (semestre=='3'):
    semestre3=pensum[2]
    if len(semestre3)==0:
        print('El semestre no tiene materias')
    else:
        codigos3=[]
        for i in semestre3.keys():
            codigos3.append(i)
        if codigo in codigos3:
           pensum[0][codigo]['nombre']=materia
           pensum[0][codigo]['créditos']=creditos
           print('Modificada con éxito')
        else:
           print('La materia no existe')
else:
    print('Ingrese un semestre válido')
    
print(pensum)
# Out:
# Modificada con éxito
# [{'0123': {'nombre': 'lectoescritura', 'créditos': 3}, '4567': {'nombre': 'inglés', 'creditos': 1}}, {}, {}]

# %%
def modificar_materia(pensum, semestre, materia, nombre, creditos):
    # ACÁ INICIA LA FUNCIÓN modificar_materia (En este espacio debes 
    # poner el código necesario para implementar esta funcionalidad)
    if (semestre==1):
        semestre1=pensum[0]
        if len(semestre1)==0:
            mensaje='El semestre no tiene materias'
        else:
            codigos1=[]
            for i in semestre1.keys():
                codigos1.append(i)
            if materia in codigos1:
               pensum[0][materia]['nombre']=nombre
               pensum[0][materia]['créditos']=creditos
               mensaje='Modificada con éxito'
            else:
               mensaje='La materia no existe'
        
    elif (semestre==2):
        semestre2=pensum[1]
        if len(semestre2)==0:
            mensaje='El semestre no tiene materias'
        else:
            codigos2=[]
            for i in semestre2.keys():
                codigos2.append(i)
            if materia in codigos2:
               pensum[1][materia]['nombre']=nombre
               pensum[1][materia]['créditos']=creditos
               mensaje='Modificada con éxito'
            else:
               mensaje='La materia no existe'
    elif (semestre==3):
        semestre3=pensum[2]
        if len(semestre3)==0:
            mensaje='El semestre no tiene materias'
        else:
            codigos3=[]
            for i in semestre3.keys():
                codigos3.append(i)
            if materia in codigos3:
               pensum[2][materia]['nombre']=nombre
               pensum[2][materia]['créditos']=creditos
               mensaje='Modificada con éxito'
            else:
               mensaje='La materia no existe'
    else:
        mensaje='Ingrese un semestre válido'
    
    
    # ACÁ TERMINA LA FUNCIÓN modificar_materia
    # NO MODIFIQUES LA SIGUIENTE LÍNEA
    return mensaje
